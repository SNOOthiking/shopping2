# %% [markdown]
# # 시계열 분석 + XGBRegressor
# - 시계열 특성을 띄는 녀석들은 시계열 분석으로
# - 나머지는 XGB분석으로
# - 변수는 전체 다 사용하기로

# %%
import pandas as pd 
import numpy as np
import itertools
from xgboost import XGBRegressor
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train = pd.read_csv('dataset/train.csv')
test =pd.read_csv('dataset/test.csv')

# %% [markdown]
# ## NaN => 0으로 채우기

# %%
train = train.fillna(0)
test = test.fillna(0)

# %%
train
# Out:
#         id  Store        Date  Temperature  Fuel_Price  Promotion1  \
# 0        1      1  05/02/2010        42.31       2.572        0.00
# 1        2      1  12/02/2010        38.51       2.548        0.00
# 2        3      1  19/02/2010        39.93       2.514        0.00
# 3        4      1  26/02/2010        46.63       2.561        0.00
# 4        5      1  05/03/2010        46.50       2.625        0.00
# ...    ...    ...         ...          ...         ...         ...
# 6250  6251     45  31/08/2012        75.09       3.867    23641.30
# 6251  6252     45  07/09/2012        75.70       3.911    11024.45
# 6252  6253     45  14/09/2012        67.87       3.948    11407.95
# 6253  6254     45  21/09/2012        65.32       4.038     8452.20
# 6254  6255     45  28/09/2012        64.88       3.997     4556.61
#
#       Promotion2  Promotion3  Promotion4  Promotion5  Unemployment  IsHoliday  \
# 0           0.00        0.00        0.00        0.00         8.106      False
# 1           0.00        0.00        0.00        0.00         8.106       True
# 2           0.00        0.00        0.00        0.00         8.106      False
# 3           0.00        0.00        0.00        0.00         8.106      False
# 4           0.00        0.00        0.00        0.00         8.106      False
# ...          ...         ...         ...         ...           ...        ...
# 6250        6.00       92.93     6988.31     3992.13         8.684      False
# 6251       12.80       52.63     1854.77     2055.70         8.684       True
# 6252        0.00        4.30     3421.72     5268.92         8.684      False
# 6253       92.28       63.24     2376.38     8670.40         8.684      False
# 6254       20.64        1.50     1601.01     3288.25         8.684      False
#
#       Weekly_Sales
# 0       1643690.90
# 1       1641957.44
# 2       1611968.17
# 3       1409727.59
# 4       1554806.68
# ...            ...
# 6250     734297.87
# 6251     766512.66
# 6252     702238.27
# 6253     723086.20
# 6254     713173.95
#
# [6255 rows x 13 columns]

# %% [markdown]
# ## Date column = datetime으로

# %%
train['Date'] = pd.to_datetime(train['Date'],format=('%d/%m/%Y'))
test['Date'] = pd.to_datetime(test['Date'],format=('%d/%m/%Y'))

# %%
fig = plt.figure(figsize=(30,60))
max_sales = max(train.Weekly_Sales)
for store in range(1,max(train.Store)+1):
    storeset = train[train.Store==store]
    ax = fig.add_subplot(12, 4, store)
    
    plt.title(f"store_{store}")
    ax.plot(storeset.Date,storeset.Weekly_Sales, label="graph", alpha=0.3,color='r')
    plt.ylim(0, max_sales)
    
plt.show()
# 3,5,9,30,33,36,37,38,42,43,44 XGBRegressor 
# 나머지 = 시계열 분석을 해보는것이 어떨까?

# %% [markdown]
# ## IsHoliday => True = 0, False=1  라벨인코딩

# %%
le = LabelEncoder()
le.fit([True,False])
train['IsHoliday']=le.transform(train['IsHoliday'])
test['IsHoliday']=le.transform(test['IsHoliday'])

# %%
train
# Out:
#         id  Store       Date  Temperature  Fuel_Price  Promotion1  Promotion2  \
# 0        1      1 2010-02-05        42.31       2.572        0.00        0.00
# 1        2      1 2010-02-12        38.51       2.548        0.00        0.00
# 2        3      1 2010-02-19        39.93       2.514        0.00        0.00
# 3        4      1 2010-02-26        46.63       2.561        0.00        0.00
# 4        5      1 2010-03-05        46.50       2.625        0.00        0.00
# ...    ...    ...        ...          ...         ...         ...         ...
# 6250  6251     45 2012-08-31        75.09       3.867    23641.30        6.00
# 6251  6252     45 2012-09-07        75.70       3.911    11024.45       12.80
# 6252  6253     45 2012-09-14        67.87       3.948    11407.95        0.00
# 6253  6254     45 2012-09-21        65.32       4.038     8452.20       92.28
# 6254  6255     45 2012-09-28        64.88       3.997     4556.61       20.64
#
#       Promotion3  Promotion4  Promotion5  Unemployment  IsHoliday  \
# 0           0.00        0.00        0.00         8.106          0
# 1           0.00        0.00        0.00         8.106          1
# 2           0.00        0.00        0.00         8.106          0
# 3           0.00        0.00        0.00         8.106          0
# 4           0.00        0.00        0.00         8.106          0
# ...          ...         ...         ...           ...        ...
# 6250       92.93     6988.31     3992.13         8.684          0
# 6251       52.63     1854.77     2055.70         8.684          1
# 6252        4.30     3421.72     5268.92         8.684          0
# 6253       63.24     2376.38     8670.40         8.684          0
# 6254        1.50     1601.01     3288.25         8.684          0
#
#       Weekly_Sales
# 0       1643690.90
# 1       1641957.44
# 2       1611968.17
# 3       1409727.59
# 4       1554806.68
# ...            ...
# 6250     734297.87
# 6251     766512.66
# 6252     702238.27
# 6253     723086.20
# 6254     713173.95
#
# [6255 rows x 13 columns]

# %% [markdown]
# ## 온도, 실업률, 연료 가격은 수치가 다르기 때문에 스케일링을 해주고 시작해야겠다.

# %%
df_train = pd.DataFrame()
df_test = pd.DataFrame()
for Store in range(1,len(train['Store'].unique())+1):
    scale =MinMaxScaler()
    X_train_sc = train[train['Store']==Store][['Temperature','Fuel_Price','Unemployment']]
    X_train_Data = train[train['Store']==Store][['Store','Date','Promotion1','Promotion2','Promotion3','Promotion4','Promotion5','IsHoliday']]
    X_train_Data = X_train_Data.reset_index(level=None,drop=True)
    scale_data = pd.DataFrame(scale.fit_transform(X_train_sc))
    scale_data.columns = ['Temperature','Fuel_Price','Unemployment']
    X_train_Data[['Temperature','Fuel_Price','Unemployment']] = scale_data
    df_train = pd.concat([df_train,X_train_Data],axis=0)

    X_test_sc = test[test['Store']==Store][['Temperature','Fuel_Price','Unemployment']]
    X_test_Data = test[test['Store']==Store][['Store','Date','Promotion1','Promotion2','Promotion3','Promotion4','Promotion5','IsHoliday']]
    X_test_Data = X_test_Data.reset_index(level=None,drop=True)
    scale_test = pd.DataFrame(scale.transform(X_test_sc))
    scale_test.columns =['Temperature','Fuel_Price','Unemployment'] 
    X_test_Data[['Temperature','Fuel_Price','Unemployment']] = scale_test
    df_test = pd.concat([df_test,X_test_Data])

# %%
df_train = df_train.reset_index(level=None,drop=True)
df_test = df_test.reset_index(level=None,drop=True)

# %%
df_test
# Out:
#      Store       Date  Promotion1  Promotion2  Promotion3  Promotion4  \
# 0        1 2012-10-05     8077.89        0.00       18.22     3617.43
# 1        1 2012-10-12     2086.18        0.00        8.11      602.36
# 2        1 2012-10-19      950.33        0.00        4.93       80.25
# 3        1 2012-10-26     2585.85       31.75        6.00     1057.16
# 4        2 2012-10-05     6037.76        0.00       10.04     3027.37
# ..     ...        ...         ...         ...         ...         ...
# 175     44 2012-10-26       38.65        2.61        0.98        0.00
# 176     45 2012-10-05     5046.74        0.00       18.82     2253.43
# 177     45 2012-10-12     1956.28        0.00        7.89      599.32
# 178     45 2012-10-19     2004.02        0.00        3.18      437.73
# 179     45 2012-10-26     4018.91       58.08      100.00      211.94
#
#      Promotion5  IsHoliday  Temperature  Fuel_Price  Unemployment
# 0       3626.14          0     0.589333    0.791816     -0.279633
# 1       5926.45          0     0.490489    0.780330     -0.279633
# 2       2312.85          0     0.579022    0.775305     -0.279633
# 3       1305.01          0     0.600178    0.712132     -0.279633
# 4       3853.40          0     0.617540    0.791816     -0.224559
# ..          ...        ...          ...         ...           ...
# 175      457.74          0     0.449955    0.924433     -0.070059
# 176     2340.01          0     0.692908    0.940746      0.427817
# 177     3990.54          0     0.516118    0.951719      0.427817
# 178     1537.49          0     0.550051    0.929042      0.427817
# 179      858.33          0     0.590431    0.865399      0.427817
#
# [180 rows x 11 columns]

# %%
df_train['Weekly_Sales'] = train['Weekly_Sales']

# %% [markdown]
#  3,5,9,30,33,36,37,38,42,43,44 번은 XGBoost 나머지는 ARIMA 모델

# %%
XGB_list = [3,5,9,30,33,36,37,38,42,43,44]

# %%
df_train1 = df_train.copy()

# %%
df_train1.index = df_train1.Date

# %%
df_train1= df_train1[['Store','Weekly_Sales']]

# %%
df_train1
# Out:
#             Store  Weekly_Sales
# Date
# 2010-02-05      1    1643690.90
# 2010-02-12      1    1641957.44
# 2010-02-19      1    1611968.17
# 2010-02-26      1    1409727.59
# 2010-03-05      1    1554806.68
# ...           ...           ...
# 2012-08-31     45     734297.87
# 2012-09-07     45     766512.66
# 2012-09-14     45     702238.27
# 2012-09-21     45     723086.20
# 2012-09-28     45     713173.95
#
# [6255 rows x 2 columns]

# %%
from pmdarima.arima import ndiffs
import pmdarima as pm

# %%
df_arima = df_train1[df_train1['Store']==1].drop('Store',axis=1)
df_arima
# Out:
#             Weekly_Sales
# Date
# 2010-02-05    1643690.90
# 2010-02-12    1641957.44
# 2010-02-19    1611968.17
# 2010-02-26    1409727.59
# 2010-03-05    1554806.68
# ...                  ...
# 2012-08-31    1582083.40
# 2012-09-07    1661767.33
# 2012-09-14    1517428.87
# 2012-09-21    1506126.06
# 2012-09-28    1437059.26
#
# [139 rows x 1 columns]

# %%
from statsmodels.tsa.stattools import adfuller
for Store in range(1,len(df_train['Store'].unique())+1):
    adf_test = adfuller(df_train1[df_train1['Store']==Store].Weekly_Sales,autolag='AIC')
    adf_test[1]<0.05

# %%
adf_test[1]
# Out:
# 1.9639415846861285e-06

# %%
kpss_diffs= ndiffs(df_arima,alpha=0.05,test='kpss',max_d=6)
adf_diffs = ndiffs(df_arima,alpha=0.05,test='adf',max_d=6)
n_diffs=max(adf_diffs,kpss_diffs)
print('차수', n_diffs)
# Out:
# 차수 1

# %%
model = pm.auto_arima(y=df_arima,
                     d=n_diffs,
                     start_p = 0,
                     max_p=3,
                     start_q=0,
                     max_q=3,
                     m= 52,
                     trace=False)

# %%
model.fit(df_arima)
# Out:
# ARIMA(order=(3, 1, 0), scoring_args={}, seasonal_order=(1, 0, 0, 52),
#       suppress_warnings=True, with_intercept=False)

# %%
model.plot_diagnostics(figsize=(20,10))

# %%
df_test1 = pd.DataFrame()

# %%
df_test1.index = df_test['Date'].unique()

# %%
model.predict(n_periods=len(df_test1))
# Out:
# array([1594095.16913544, 1520576.99768598, 1532758.89467833,
#        1494637.4005147 ])

# %%
        model = XGBRegressor()
        train_X = df_train[df_train['Store']==Store].iloc[:,2:-1]
        train_y = df_train[df_train['Store']==Store].iloc[:,-1]
        model.fit(train_X,train_y)
        test_X = df_test[df_test['Store']==Store].iloc[:,2:]
        pred= model.predict(test_X)
        pred
# Out:
# array([719416.6 , 698240.25, 747298.94, 784396.94], dtype=float32)

# %% [markdown]
# # 정상성 검증 adf_test
# - p-value >0.05 = 정상성 X 로그를 취해준다
# - p-value <0.05 = 정상성 = arima

# %%
result = []
for Store in range(1,len(df_train['Store'].unique())+1):
    if Store in XGB_list:
        model = XGBRegressor()
        train_X = df_train[df_train['Store']==Store].iloc[:,2:-1]
        train_y = df_train[df_train['Store']==Store].iloc[:,-1]
        model.fit(train_X,train_y)
        test_X = df_test[df_test['Store']==Store].iloc[:,2:]
        pred= model.predict(test_X)
        result.append(pred)
    else:
        df_arima = df_train1[df_train1['Store']==Store].drop('Store',axis=1)
        adf_test = adfuller(df_arima,autolag='AIC')
        if adf_test[1]>0.05:
            df_arima = np.log(df_arima)
            kpss_diffs= ndiffs(df_arima,alpha=0.05,test='kpss',max_d=6)
            adf_diffs = ndiffs(df_arima,alpha=0.05,test='adf',max_d=6)
            n_diffs=max(adf_diffs,kpss_diffs)
            model = pm.auto_arima(y=df_arima,
                         d=n_diffs,
                         start_p = 0,
                         max_p=3,
                         start_q=0,
                         max_q=3,
                         m= 52,
                         seasonal=True,
                         trace=False)
            model.fit(df_arima)
            pred = np.exp(model.predict(n_periods=len(df_test1)))
            result.append(pred)
        else:
            kpss_diffs= ndiffs(df_arima,alpha=0.05,test='kpss',max_d=6)
            adf_diffs = ndiffs(df_arima,alpha=0.05,test='adf',max_d=6)
            n_diffs=max(adf_diffs,kpss_diffs)
            model = pm.auto_arima(y=df_arima,
                         d=n_diffs,
                         start_p = 0,
                         max_p=3,
                         start_q=0,
                         max_q=3,
                         m= 52,
                         seasonal=True,
                         trace=False)
            model.fit(df_arima)
            pred = model.predict(n_periods=len(df_test1))
            result.append(pred)

# %%
import itertools

# %%
result = list(itertools.chain(*np.around(result,2)))

# %%
sub = pd.read_csv('dataset/sample_submission.csv')

# %%
sub['Weekly_Sales']=result

# %%
sub.to_csv('submission15.csv',index=False)

# %%
sub
# Out:
#       id  Weekly_Sales
# 0      1    1594095.17
# 1      2    1520577.00
# 2      3    1532758.89
# 3      4    1494637.40
# 4      5    1881168.44
# ..   ...           ...
# 175  176     321814.22
# 176  177     757611.16
# 177  178     747677.28
# 178  179     782529.89
# 179  180     790996.85
#
# [180 rows x 2 columns]
