# %%
import pandas as pd 
import numpy as np
import itertools
from xgboost import XGBRegressor
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train = pd.read_csv('dataset/train.csv')
test =pd.read_csv('dataset/test.csv')

# %% [markdown]
# ## NaN => 0으로 채우기

# %%
train = train.fillna(0)
test = test.fillna(0)

# %% [markdown]
# ## Date column = datetime으로

# %%
train['Date'] = pd.to_datetime(train['Date'],format=('%d/%m/%Y'))
test['Date'] = pd.to_datetime(test['Date'],format=('%d/%m/%Y'))

# %% [markdown]
# ## IsHoliday => True = 0, False=1 라벨인코딩

# %%
le = LabelEncoder()
le.fit([True,False])
train['IsHoliday']=le.transform(train['IsHoliday'])
test['IsHoliday']=le.transform(test['IsHoliday'])

# %% [markdown]
# ## 온도, 실업률, 연료 가격은 수치가 다르기 때문에 스케일링을 해주고 시작해야겠다.

# %%
df_train = pd.DataFrame()
df_test = pd.DataFrame()
for Store in range(1,len(train['Store'].unique())+1):
    scale =MinMaxScaler()
    X_train_sc = train[train['Store']==Store][['Temperature','Fuel_Price','Unemployment']]
    X_train_Data = train[train['Store']==Store].iloc[:,[1,5,6,7,8,9,11]]
    X_train_Data = X_train_Data.reset_index(level=None,drop=True)
    scale_data = pd.DataFrame(scale.fit_transform(X_train_sc))
    scale_data.columns = ['Temperature','Fuel_Price','Unemployment']
    X_train_Data[['Temperature','Fuel_Price','Unemployment']] = scale_data
    df_train = pd.concat([df_train,X_train_Data],axis=0)

    X_test_sc = test[test['Store']==Store][['Temperature','Fuel_Price','Unemployment']]
    X_test_Data = test[test['Store']==Store].iloc[:,[1,5,6,7,8,9,11]]
    X_test_Data = X_test_Data.reset_index(level=None,drop=True)
    scale_test = pd.DataFrame(scale.transform(X_test_sc))
    scale_test.columns =['Temperature','Fuel_Price','Unemployment'] 
    X_test_Data[['Temperature','Fuel_Price','Unemployment']] = scale_test
    df_test = pd.concat([df_test,X_test_Data])

# %%
df_train = df_train.reset_index(level=None,drop=True)
df_test = df_test.reset_index(level=None,drop=True)

# %%
df_train['Weekly_Sales'] = train['Weekly_Sales']

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df_train.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 다중공선성 확인 및 유의수준 확인
# - promotion4 는 유의미하지 않다는것을 확인 할 수 있다.

# %%
from statsmodels.formula.api import ols
model = ols('Weekly_Sales~Temperature+Fuel_Price+Promotion1+Promotion2+Promotion3+Promotion4+Promotion5+Unemployment+IsHoliday',df_train)
res = model.fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           Weekly_Sales   R-squared:                       0.064
# Model:                            OLS   Adj. R-squared:                  0.063
# Method:                 Least Squares   F-statistic:                     47.50
# Date:                Tue, 02 Aug 2022   Prob (F-statistic):           1.61e-83
# Time:                        09:11:42   Log-Likelihood:                -91518.
# No. Observations:                6255   AIC:                         1.831e+05
# Df Residuals:                    6245   BIC:                         1.831e+05
# Df Model:                           9
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept     1.125e+06   2.95e+04     38.124      0.000    1.07e+06    1.18e+06
# Temperature  -9178.4522   2.71e+04     -0.339      0.735   -6.23e+04    4.39e+04
# Fuel_Price   -1.814e+05   2.75e+04     -6.593      0.000   -2.35e+05   -1.27e+05
# Promotion1      15.8710      2.382      6.662      0.000      11.201      20.541
# Promotion2       4.4684      1.489      3.002      0.003       1.550       7.386
# Promotion3      12.7228      1.347      9.448      0.000      10.083      15.363
# Promotion4      -4.9416      3.434     -1.439      0.150     -11.674       1.791
# Promotion5      14.2480      1.908      7.468      0.000      10.508      17.988
# Unemployment -7.916e+04   2.61e+04     -3.032      0.002    -1.3e+05    -2.8e+04
# IsHoliday    -1.548e+04   2.87e+04     -0.539      0.590   -7.17e+04    4.08e+04
# ==============================================================================
# Omnibus:                      442.584   Durbin-Watson:                   0.147
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              540.287
# Skew:                           0.713   Prob(JB):                    4.77e-118
# Kurtosis:                       3.193   Cond. No.                     4.77e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.77e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ## VIF 를 이용한 다중공선성 확인, 높은것중 하나를 제거
# - 위에서 프로모션4번이 좋지않았기 때문에 4번을 제거하도록 한다.

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
model.exog_names
pd.DataFrame({'컬럼': column, 'VIF': variance_inflation_factor(model.exog, i)} 
             for i, column in enumerate(model.exog_names)
             if column != 'Intercept')
# Out:
#              컬럼       VIF
# 0   Temperature  1.115769
# 1    Fuel_Price  1.544252
# 2    Promotion1  4.166379
# 3    Promotion2  1.131665
# 4    Promotion3  1.082514
# 5    Promotion4  3.552805
# 6    Promotion5  1.286687
# 7  Unemployment  1.596928
# 8     IsHoliday  1.147837

# %%
df_train = df_train.drop('Promotion4',axis=1)

# %%
model1 = ols('Weekly_Sales~Temperature+Fuel_Price+Promotion1+Promotion2+Promotion3+Promotion5+Unemployment+IsHoliday',df_train)
res = model1.fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           Weekly_Sales   R-squared:                       0.064
# Model:                            OLS   Adj. R-squared:                  0.063
# Method:                 Least Squares   F-statistic:                     53.17
# Date:                Tue, 02 Aug 2022   Prob (F-statistic):           5.93e-84
# Time:                        09:11:42   Log-Likelihood:                -91519.
# No. Observations:                6255   AIC:                         1.831e+05
# Df Residuals:                    6246   BIC:                         1.831e+05
# Df Model:                           8
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept     1.123e+06   2.95e+04     38.094      0.000    1.07e+06    1.18e+06
# Temperature  -7476.2919   2.71e+04     -0.276      0.782   -6.05e+04    4.56e+04
# Fuel_Price   -1.769e+05   2.73e+04     -6.470      0.000    -2.3e+05   -1.23e+05
# Promotion1      13.0468      1.350      9.663      0.000      10.400      15.693
# Promotion2       4.6234      1.485      3.114      0.002       1.713       7.534
# Promotion3      12.7233      1.347      9.448      0.000      10.083      15.363
# Promotion5      14.4351      1.904      7.583      0.000      10.703      18.167
# Unemployment  -7.99e+04   2.61e+04     -3.061      0.002   -1.31e+05   -2.87e+04
# IsHoliday     -1.62e+04   2.87e+04     -0.565      0.572   -7.25e+04    4.01e+04
# ==============================================================================
# Omnibus:                      440.964   Durbin-Watson:                   0.147
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              537.938
# Skew:                           0.712   Prob(JB):                    1.54e-117
# Kurtosis:                       3.191   Cond. No.                     4.33e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.33e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
model1.exog_names
pd.DataFrame({'컬럼': column, 'VIF': variance_inflation_factor(model1.exog, i)} 
             for i, column in enumerate(model1.exog_names)
             if column != 'Intercept')
# Out:
#              컬럼       VIF
# 0   Temperature  1.113641
# 1    Fuel_Price  1.523799
# 2    Promotion1  1.337996
# 3    Promotion2  1.125737
# 4    Promotion3  1.082514
# 5    Promotion5  1.280706
# 6  Unemployment  1.596316
# 7     IsHoliday  1.147483

# %%
df_test.drop('Promotion4',axis=1,inplace=True)

# %%
df_train
# Out:
#       Store  Promotion1  Promotion2  Promotion3  Promotion5  IsHoliday  \
# 0         1        0.00        0.00        0.00        0.00          0
# 1         1        0.00        0.00        0.00        0.00          1
# 2         1        0.00        0.00        0.00        0.00          0
# 3         1        0.00        0.00        0.00        0.00          0
# 4         1        0.00        0.00        0.00        0.00          0
# ...     ...         ...         ...         ...         ...        ...
# 6250     45    23641.30        6.00       92.93     3992.13          0
# 6251     45    11024.45       12.80       52.63     2055.70          1
# 6252     45    11407.95        0.00        4.30     5268.92          0
# 6253     45     8452.20       92.28       63.24     8670.40          0
# 6254     45     4556.61       20.64        1.50     3288.25          0
#
#       Temperature  Fuel_Price  Unemployment  Weekly_Sales
# 0        0.122844    0.041637      1.000000    1643690.90
# 1        0.055289    0.024408      1.000000    1641957.44
# 2        0.080533    0.000000      1.000000    1611968.17
# 3        0.199644    0.033740      1.000000    1409727.59
# 4        0.197333    0.079684      1.000000    1554806.68
# ...           ...         ...           ...           ...
# 6250     0.865965    0.854426      0.457746     734297.87
# 6251     0.876315    0.886613      0.457746     766512.66
# 6252     0.743468    0.913680      0.457746     702238.27
# 6253     0.700204    0.979517      0.457746     723086.20
# 6254     0.692738    0.949525      0.457746     713173.95
#
# [6255 rows x 10 columns]

# %%
df_test
# Out:
#      Store  Promotion1  Promotion2  Promotion3  Promotion5  IsHoliday  \
# 0        1     8077.89        0.00       18.22     3626.14          0
# 1        1     2086.18        0.00        8.11     5926.45          0
# 2        1      950.33        0.00        4.93     2312.85          0
# 3        1     2585.85       31.75        6.00     1305.01          0
# 4        2     6037.76        0.00       10.04     3853.40          0
# ..     ...         ...         ...         ...         ...        ...
# 175     44       38.65        2.61        0.98      457.74          0
# 176     45     5046.74        0.00       18.82     2340.01          0
# 177     45     1956.28        0.00        7.89     3990.54          0
# 178     45     2004.02        0.00        3.18     1537.49          0
# 179     45     4018.91       58.08      100.00      858.33          0
#
#      Temperature  Fuel_Price  Unemployment
# 0       0.589333    0.791816     -0.279633
# 1       0.490489    0.780330     -0.279633
# 2       0.579022    0.775305     -0.279633
# 3       0.600178    0.712132     -0.279633
# 4       0.617540    0.791816     -0.224559
# ..           ...         ...           ...
# 175     0.449955    0.924433     -0.070059
# 176     0.692908    0.940746      0.427817
# 177     0.516118    0.951719      0.427817
# 178     0.550051    0.929042      0.427817
# 179     0.590431    0.865399      0.427817
#
# [180 rows x 9 columns]

# %%
result = []
for Store in range(1,len(df_train['Store'].unique())+1):
    model = XGBRegressor()
    train_X = df_train[df_train['Store']==Store].iloc[:,1:-1]
    train_y = df_train[df_train['Store']==Store].iloc[:,-1]
    model.fit(train_X,train_y)
    test_X = df_test[df_test['Store']==Store].iloc[:,1:]
    pred= model.predict(test_X)
    result.append(pred)

# %%
result
# Out:
# [array([1608123.2, 1512356.1, 1581347.8, 1611476.2], dtype=float32),
#  array([1803975.9, 1841405.8, 1732396.1, 1771796.1], dtype=float32),
#  array([407764.7 , 405731.88, 408036.6 , 394819.56], dtype=float32),
#  array([2289433. , 2160980.2, 2110567.5, 2119004. ], dtype=float32),
#  array([322109.03, 305073.34, 302134.5 , 309399.56], dtype=float32),
#  array([1473513.1, 1508496.5, 1450759.4, 1531747.2], dtype=float32),
#  array([485142.4 , 566058.9 , 534321.1 , 604541.06], dtype=float32),
#  array([910617.56, 893761.56, 917364.  , 901313.5 ], dtype=float32),
#  array([531294.56, 559859.1 , 565743.25, 544779.3 ], dtype=float32),
#  array([1758737.4, 1816971.9, 1867188.4, 1867406.8], dtype=float32),
#  array([1360698.1, 1403897.2, 1332772.5, 1386507.9], dtype=float32),
#  array([ 914437.7 ,  981643.5 ,  981034.06, 1019040.8 ], dtype=float32),
#  array([2032056.2, 1841220.5, 1876172.4, 2141957.8], dtype=float32),
#  array([1622280.8, 1575702. , 1671132.9, 1569784.5], dtype=float32),
#  array([548135.44, 563493.1 , 561082.56, 594730.94], dtype=float32),
#  array([465659.34, 470070.6 , 472759.8 , 471226.25], dtype=float32),
#  array([964581.6, 873575.4, 928201. , 836501.9], dtype=float32),
#  array([ 995701.56,  984450.2 ,  967671.6 , 1054341.  ], dtype=float32),
#  array([1325398.5, 1340519.5, 1340019.1, 1351892.5], dtype=float32),
#  array([1951789.9, 2111118. , 2021911.5, 2020784.8], dtype=float32),
#  array([730207.7, 695318.7, 689281.7, 768531.2], dtype=float32),
#  array([ 950644.6 , 1040491.06,  977657.06, 1024719.44], dtype=float32),
#  array([1296151.4, 1262908.8, 1241864.1, 1387202.8], dtype=float32),
#  array([1271064.1, 1341960.2, 1346158.4, 1337816.9], dtype=float32),
#  array([682753.9 , 697180.5 , 656434.56, 668091.25], dtype=float32),
#  array([ 968774.6 , 1026561.75,  942477.7 ,  986894.25], dtype=float32),
#  array([1654764.6, 1652977.8, 1638029.5, 1678502.1], dtype=float32),
#  array([1380814.5, 1218427.8, 1298121.9, 1181469.8], dtype=float32),
#  array([508931.53, 525068.25, 493274.62, 531642.75], dtype=float32),
#  array([440415.2 , 441316.38, 449583.28, 449203.53], dtype=float32),
#  array([1372488.4, 1428012.1, 1380480.9, 1339862.1], dtype=float32),
#  array([1194709.8, 1157872.4, 1166322.6, 1143358.8], dtype=float32),
#  array([268849.84, 266717.38, 261952.81, 271881.56], dtype=float32),
#  array([970312.8, 964847.3, 960080.8, 951049.5], dtype=float32),
#  array([754047.6 , 760268.5 , 738835.94, 771839.1 ], dtype=float32),
#  array([300411.9 , 300465.7 , 309771.84, 305000.75], dtype=float32),
#  array([528217.7 , 527889.2 , 525157.9 , 528995.44], dtype=float32),
#  array([403473.88, 440501.12, 449589.66, 434860.22], dtype=float32),
#  array([1541164.6, 1501021.8, 1523107.4, 1466547. ], dtype=float32),
#  array([899271.25, 889330.5 , 876525.56, 991258.94], dtype=float32),
#  array([1365944.2, 1436067.6, 1343989.2, 1284850.6], dtype=float32),
#  array([596392.7 , 601817.2 , 612337.06, 583283.5 ], dtype=float32),
#  array([614993.2, 634507.4, 640145.5, 636234.4], dtype=float32),
#  array([336117.53, 337850.75, 331760.56, 323079.06], dtype=float32),
#  array([718697.7, 691878.6, 742226.1, 783645. ], dtype=float32)]

# %%
result = list(itertools.chain(*np.around(result,2)))

# %%
len(result)
# Out:
# 180

# %%
submission = pd.read_csv('dataset/sample_submission.csv')

# %%
submission['Weekly_Sales'] = result

# %%
submission.to_csv('submission10.csv',index = False)
